# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
tup = [(12,15),(42,48),(41,16),(15,12),(22,55),(12,19)]
number = int(input('Enter number: '))
count = 0;

for a,b in tup:
    if(a%number==0 and b%number==0):
        print(str(a)+','+str(b))
        count=count+1
if count==0:
    print('No element in tuple is divisible by {}'.format(number))
# Out:
# Enter number: 11
# 22,55

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
tup = tuple(input('Enter tuple: '))
string = str(input('Enter string: '))
li=[]

for a in tup:
    li.append(a+string)
print(li)
# Out:
# Enter tuple: abcde
# Enter string: Z
# ['aZ', 'bZ', 'cZ', 'dZ', 'eZ']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
tup = [(-12,15),(-42,48),(41,16),(-15,12),(22,55),(-12,19)]
count = 0;

for a,b in tup:
    if(a>0 and b>0):
        print(str(a)+','+str(b))
        count=count+1
if count==0:
    print('No element in tuple is positive')
# Out:
# 41,16
# 22,55

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
tup = tuple(input('Enter tuple: '))
number = str(input('Enter element: '))
count=0

for i in tup:
    if(i==number):
        count=count+1
        
print('{} frequency is {}'.format(number,count))
# Out:
# Enter tuple: 5165165465
# Enter element: 5
# 5 frequency is 4

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
tup = [(101010),(100010),(10101010),(1010101)]
li=[]

for i in tup:
    li.append(int(str(i),2))
print(li)
# Out:
# [42, 34, 170, 85]

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
tup = tuple(input('Enter tuple: '))
li = list(input('Enter list: '))
print('\n')

for i in range(0,len(li)):
    for j in range(0,len(tup)):
        count=0
        if(tup[j]==li[i]):
            count+=1
        if count!=0:
            print('list element {} found in tuple at position {}'.format(li[i],j+1))
# Out:
# Enter tuple: 132121654121
# Enter list: 12
#
#
# list element 1 found in tuple at position 1
# list element 1 found in tuple at position 4
# list element 1 found in tuple at position 6
# list element 1 found in tuple at position 10
# list element 1 found in tuple at position 12
# list element 2 found in tuple at position 3
# list element 2 found in tuple at position 5
# list element 2 found in tuple at position 11
