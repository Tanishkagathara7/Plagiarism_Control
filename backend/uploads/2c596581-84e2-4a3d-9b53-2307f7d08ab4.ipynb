# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
tup = [(2, 8, 40), (7, 12, 0), (12, 18, 21), (6, 44, 58)] 
print(str(tup))
K = int(input('Enter value of K: '))
ans = [i for i in tup if all(j % K == 0 for j in i)]
print(ans)
# Out:
# [(2, 8, 40), (7, 12, 0), (12, 18, 21), (6, 44, 58)]
# Enter value of K: 2
# [(2, 8, 40), (6, 44, 58)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
print("---Enter comma seperated values---")
tup=tuple([(i) for i in input().split(',')]);
print(tup)
add=input('Enter string which u want to add after every elements: ')
ans=[i for j in tup for i in (j,add)]
print(ans)
# Out:
# ---Enter comma seperated values---
# Darshan,LE,GCET,Marwadi
# ('Darshan', 'LE', 'GCET', 'Marwadi')
# Enter string which u want to add after every elements: College
# ['Darshan', 'College', 'LE', 'College', 'GCET', 'College', 'Marwadi', 'College']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
tup = [(1, -1, 0), (-3, 6, 9), (2, 7, 4), (10, 3)]
print(tup)
ans = [i for i in tup if all(j>=0 for j in i)]
print(ans)
# Out:
# [(1, -1, 0), (-3, 6, 9), (2, 7, 4), (10, 3)]
# [(2, 7, 4), (10, 3)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
print("---Enter comma seperated values---")
tup=tuple([int(i) for i in input().split(',')]);
print(tup)
f=0
for i in tup:
    if tup.index(i)==f:
        print(i,'---',tup.count(i))
    f+=1
# Out:
# ---Enter comma seperated values---
# 1,2,3,3,3,4,4,5,5,5,5,5,6,6,7,8,7,7,8,9,0,1,1,1,1
# (1, 2, 3, 3, 3, 4, 4, 5, 5, 5, 5, 5, 6, 6, 7, 8, 7, 7, 8, 9, 0, 1, 1, 1, 1)
# 1 --- 5
# 2 --- 1
# 3 --- 3
# 4 --- 2
# 5 --- 5
# 6 --- 2
# 7 --- 3
# 8 --- 2
# 9 --- 1
# 0 --- 1

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
print("---Enter comma seperated values---")
tup=tuple([i for i in input().split(',')])
ans = int("".join(str(i) for i in tup), 2)
print(ans)
# Out:
# ---Enter comma seperated values---
# 1,1,1,1,1,1,1,1
# 255

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
print("---Enter comma seperated values---")
tup=tuple([i for i in input().split(',')])
print(tup)
find=input("Enter value u want to find: ")
if find in tup:
    print(find,"is present.")
else:
    print("Not found !")
# Out:
# ---Enter comma seperated values---
# Darshan,Institute,Of,Engineering,And,Technology
# ('Darshan', 'Institute', 'Of', 'Engineering', 'And', 'Technology')
# Enter value u want to find: Engineering
# Engineering is present.
