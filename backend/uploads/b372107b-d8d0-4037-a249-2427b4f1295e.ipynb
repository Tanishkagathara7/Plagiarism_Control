# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
tuple = [(6, 24, 12), (7, 9, 6), (12, 18, 21)] 
print("The Given Tuple is : " + str(tuple)) 
K = 6
res = list(filter(lambda sub: all(ele % K == 0 for ele in sub), tuple)) 
print( K," Multiple elements tuples : " + str(res))
# Out:
# The Given Tuple is : [(6, 24, 12), (7, 9, 6), (12, 18, 21)]
# 6  Multiple elements tuples : [(6, 24, 12)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
tuple = (5,6,7,8) 
print("The Given Tuple is : " + str(tuple)) 
K = "Joker"
res = [ele for sub in tuple for ele in (sub, K)] 
print("Converted Tuple with K : ", res)
# Out:
# The Given Tuple is : (5, 6, 7, 8)
# Converted Tuple with K :  [5, 'Joker', 6, 'Joker', 7, 'Joker', 8, 'Joker']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
tuple = (5,6,-1,8) 
print("The Given Tuple is : " + str(tuple)) 
print("Above tuple of postive no:")
for i in tuple:
    if(i>0):
        print(i)
# Out:
# The Given Tuple is : (5, 6, -1, 8)
# Above tuple of postive no:
# 5
# 6
# 8

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
tuple = [('Mansi', 1), ('Degda', 2), ('Degda', 3)] 
print ("The Given Tuple is : " + str(tuple)) 
res = list(map(lambda i : i[0], tuple)).count('Mansi') 
print ("The frequency of element is : " + str(res))
# Out:
# The Given Tuple is : [('Mansi', 1), ('Degda', 2), ('Degda', 3)]
# The frequency of element is : 1

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
tuple = (1, 1, 0, 1, 0, 0, 1) 
print("The Given tuple is : " + str(tuple)) 
res = int("".join(str(ele) for ele in tuple), 2)  
print("Decimal number is : " + str(res))
# Out:
# The Given tuple is : (1, 1, 0, 1, 0, 0, 1)
# Decimal number is : 105

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
tuple = (5,6,-1,8) 
b=0
n=int(input("Enter the no to find:"))
print("The Given Tuple is : " + str(tuple)) 
for i in tuple:
    if(i==n):
        b=1
if(b==1):
    print("Given no is present in Tuple")
else :
    print("Given no is not present in Tuple")
# Out:
# Enter the no to find:0
# The Given Tuple is : (5, 6, -1, 8)
# Given no is not present in Tuple
