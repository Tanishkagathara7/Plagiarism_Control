# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
numbers = [(1,12,34),(12,30,48),(15,45,90)]
K = int(input("Enter the K : "))
ans = [temp for temp in numbers if all(temp1 % K == 0 for temp1 in temp)]
print(str(ans))
# Out:
# Enter the K : 6
# [(12, 30, 48)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
tuple1 = (1,3,5,7,9)
user_input = input("Enter the string : ")
ans = [i for i in tuple1 for i in (i,user_input)]
print(ans)
# Out:
# Enter the string : even
# [1, 'even', 3, 'even', 5, 'even', 7, 'even', 9, 'even']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
tuple1 = [(-1,-3,-4,5),(21,13,41,5),(12,34,56,-1)]
ans = [i for i in tuple1 if all(element >=0 for element in i)]
print(ans)
# Out:
# [(21, 13, 41, 5)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
tuple1 = [('Hello',1),('How',2),('are',3),('Hello',4)]
ans = list(map(lambda i:i[0],tuple1)).count('Hello')
print("The Frequency of given word is ",ans)
# Out:
# The Frequency of given word is  2

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
tuple1 = (1,0,0,0)
ans = int("".join(str(element) for element in tuple1),2)
print("The decimal of given binary is ",str(ans))
# Out:
# The decimal of given binary is  8

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
tuple1 = (("Hello",1),("World",2))
if(any('World') in i for i in tuple1):
    print("presen")
else:
    pri
