# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
test_list = [(3, 6, 12), (2, 4, 6), (12, 18, 21)] 
  
print("The original list is : " + str(test_list)) 
  
K = 2
  
res = list(filter(lambda sub: all(ele % K == 0 for ele in sub), test_list)) 
   
print("K Multiple elements tuples : " + str(res))
# Out:
# The original list is : [(3, 6, 12), (2, 4, 6), (12, 18, 21)]
# K Multiple elements tuples : [(2, 4, 6)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
test_tup = (5, 6, 7, 4, 9) 
 
print("The original tuple is : ", test_tup) 
   
K = "vishva"
   
res = [ele for sub in test_tup for ele in (sub, K)] 
   
print("Converted Tuple with K : ", res)
# Out:
# The original tuple is :  (5, 6, 7, 4, 9)
# Converted Tuple with K :  [5, 'vishva', 6, 'vishva', 7, 'vishva', 4, 'vishva', 9, 'vishva']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
test_list = [(4, 5, -9), (-6, 2, 5), (-7, 3, 5), (4, 6, 2)] 
   
print("The original list is : " + str(test_list)) 
   
res = [sub for sub in test_list if all(ele >= 0 for ele in sub)] 
   
print("Positive elements Tuples : " + str(res))
# Out:
# The original list is : [(4, 5, -9), (-6, 2, 5), (-7, 3, 5), (4, 6, 2)]
# Positive elements Tuples : [(4, 6, 2)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
from collections import Counter 
   
test_l = [('vishva', 1), ('atulbhai', 2), ('adhiya', 3)] 
   
print ("The original list is : " + str(test_l)) 
 
res = Counter(i[0] for i in test_l) 
   
print ("The frequency of element is : " + str(res['Word']))
# Out:
# The original list is : [('vishva', 1), ('atulbhai', 2), ('adhiya', 3)]
# The frequency of element is : 0

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
test_tup = (2, 6, 7) 
  
print("The original tuple : " + str(test_tup)) 
   
res = int(''.join(map(str, test_tup))) 
  
print("Tuple to integer conversion : " + str(res))
# Out:
# The original tuple : (2, 6, 7)
# Tuple to integer conversion : 267

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
test_tuple = (("Python", "dataScience"), ("CS", "cybersecurity")) 
   
print ("The original tuple is " + str(test_tuple)) 
 
if (any('Python' in i for i in test_tuple)) : 
    print("Python is present") 
else : 
    print("Python is not present")
# Out:
# The original tuple is (('Python', 'dataScience'), ('CS', 'cybersecurity'))
# Python is present
