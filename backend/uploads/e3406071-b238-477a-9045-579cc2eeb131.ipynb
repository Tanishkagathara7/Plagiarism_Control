# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
list = [(6, 24, 12), (7, 9, 6), (12, 18, 21)]  
print("The original list is : " + str(list)) 
K = 6
res = [sub for sub in list if all(ele % K == 0 for ele in sub)]  
print("K Multiple elements tuples : " + str(res))
# Out:
# The original list is : [(6, 24, 12), (7, 9, 6), (12, 18, 21)]
# K Multiple elements tuples : [(6, 24, 12)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
tup = (5, 6, 7, 4, 9) 
print("The original tuple is : ", tup)  
string = "hello"
res = [ele for sub in test_tup for ele in (sub, string)] 
print("Converted Tuple with string : ", res)
# Out:
# The original tuple is :  (5, 6, 7, 4, 9)
# Converted Tuple with string :  [5, 'hello', 6, 'hello', 7, 'hello', 4, 'hello', 9, 'hello']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
list = [(4, 5, 9), (-3, 2, 3), (-3, 5, 6), (4, 6)] 
print("The original list is : " + str(list)) 
res = [sub for sub in list if all(ele >= 0 for ele in sub)] 
print("Positive elements of Tuples : " + str(res))
# Out:
# The original list is : [(4, 5, 9), (-3, 2, 3), (-3, 5, 6), (4, 6)]
# Positive elements of Tuples : [(4, 5, 9), (4, 6)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
from collections import Counter
list = [('2', '3'), ('4', '2'), ('1', '4')]
print("Given list of tuples : " ,list)
Freq_res = Counter(i[0] for i in list)['2']
print("The frequency of element is : ",Freq_res)
# Out:
# Given list of tuples :  [('2', '3'), ('4', '2'), ('1', '4')]
# The frequency of element is :  1

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
tup = (1, 1, 0, 1, 0, 0, 1 , 1) 
print("The original tuple is : " + str(tup)) 
res = int("".join(str(ele) for ele in tup), 2)   
print("integer number is : " + str(res))
# Out:
# The original tuple is : (1, 1, 0, 1, 0, 0, 1, 1)
# integer number is : 211

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
tup = (2, 5, 7, 1, 3) 
print("The original tuple is : " + str(tup)) 
list = [1, 3, 2, 7] 
res = False 
for i in list: 
    if i in tup : 
        res = True 
        break 
print("Is any list element present in tuple : " + str(res))
# Out:
# The original tuple is : (2, 5, 7, 1, 3)
# Is any list element present in tuple : True
