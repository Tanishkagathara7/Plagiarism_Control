# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
tuple = [(6, 24, 12), (7, 9, 6), (14, 28, 21)]
k = int(input("Enter the value of K : "))
res = list(filter(lambda sub: all(element % k == 0 for element in sub), tuple))
print("K Multiple elements tuples : " + str(res))
# Out:
# Enter the value of K : 7
# K Multiple elements tuples : [(14, 28, 21)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
tuple = (5, 6, 7, 4, 9)
K = "Add"
res = [element for sub in tuple for element in (sub, K)] 
print("Converted Tuple with K : ", res)
# Out:
# Converted Tuple with K :  [5, 'Add', 6, 'Add', 7, 'Add', 4, 'Add', 9, 'Add']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
tuple = [(4, 5, 9), (-3, 2, 3), (-3, 5, 6), (4, 6)]   
res = [sub for sub in tuple if all(ele >= 0 for ele in sub)] 
print("Positive elements Tuples : " + str(res))
# Out:
# Positive elements Tuples : [(4, 5, 9), (4, 6)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
tuple = [('Apple', 'Mon'), ('Banana', 'Tue'), ('Apple', 'Wed')]
print("Given list of tuples : " ,tuple)
Freq_res = list(map(lambda i: i[0], tuple)).count('Apple')
print("The frequency of element is : ",Freq_res)
# Out:
# Given list of tuples :  [('Apple', 'Mon'), ('Banana', 'Tue'), ('Apple', 'Wed')]
# The frequency of element is :  2

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
tuple = (1, 1, 0, 1, 0, 0, 1, 1) 
print("The original tuple is : " + str(tuple)) 
res = int("".join(str(ele) for ele in tuple), 3)    
print("Decimal number is : " + str(res))
# Out:
# The original tuple is : (1, 1, 0, 1, 0, 0, 1, 1)
# Decimal number is : 3001

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
tuple = [('Mon',10),('Tue',8),('Wed',8),('Thu',5)]
print("Given tuple: ",tuple)
if any('Tue' in i for i in tuple):
    print("present")
else :
    print("Not present")
# Out:
# Given tuple:  [('Mon', 10), ('Tue', 8), ('Wed', 8), ('Thu', 5)]
# present
