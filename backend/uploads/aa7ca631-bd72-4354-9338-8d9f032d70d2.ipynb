# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
test_list = [(6, 24, 12), (7, 9, 6), (12, 18, 21)] 
  
print("The original list is : " + str(test_list)) 
  
K = 6
  
res = [sub for sub in test_list if all(ele % K == 0 for ele in sub)] 
  
print("K Multiple elements tuples : " + str(res))
# Out:
# The original list is : [(6, 24, 12), (7, 9, 6), (12, 18, 21)]
# K Multiple elements tuples : [(6, 24, 12)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
testTup = (5, 6, 7, 4, 9) 
  
print("Tuple = ", testTup) 
  
K = "str"
  
res = [ele for sub in test_tup for ele in (sub, K)] 
  
print(" Tuple with K : ", res)
# Out:
# Tuple =  (5, 6, 7, 4, 9)
#  Tuple with K :  [5, 'str', 6, 'str', 7, 'str', 4, 'str', 9, 'str']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
test_list = [(4, 5, 9), (-3, 12, 3), (-3, 5, -6), (4, 6)] 
  
print("List = " + str(test_list)) 
  
res = [sub for sub in test_list if all(ele >= 0 for ele in sub)] 
  
print("Positive = " + str(res))
# Out:
# List = [(4, 5, 9), (-3, 12, 3), (-3, 5, -6), (4, 6)]
# Positive = [(4, 5, 9), (4, 6)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
test_list = [('Tony', 1), ('Stark', 2), ('Tomy', 3)] 
  
print ("list = " + str(test_list)) 
  
res = list(map(lambda i : i[0], test_list)).count('Tony') 
  
print ("Frequency = " + str(res))
# Out:
# list = [('Tony', 1), ('Stark', 2), ('Tomy', 3)]
# Frequency = 1

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
import functools 
  
test_tuple = (7, 7, 7) 
  
print("Tuple : " + str(test_tuple)) 
  
res = functools.reduce(lambda sub, ele: sub * 10 + ele, test_tuple) 
  
print("Integer = " + str(res))
# Out:
# Tuple : (7, 7, 7)
# Integer = 777

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
test_tuple = (("TonyStark", "Ts"), ("MrStark", "Mr")) 
  
print ("Tuple = " + str(test_tuple)) 
  
if (any('TonyStark' in i for i in test_tuple)) : 
    print("TonyStark is present") 
else : 
    print("TonyStark is not present")
# Out:
# Tuple = (('TonyStark', 'Ts'), ('MrStark', 'Mr'))
# TonyStark is present
