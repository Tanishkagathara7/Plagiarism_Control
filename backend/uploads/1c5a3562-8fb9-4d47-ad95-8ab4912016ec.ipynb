# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
List = [(60, 24, 12), (75, 19, 26), (12, 45, 21)] 
print("The original list is : " + str(List)) 

K = 6
res = [a for a in List if all(element % K == 0 for element in a)] 
print("K Multiple elements tuples : " + str(res))
# Out:
# The original list is : [(60, 24, 12), (75, 19, 26), (12, 45, 21)]
# K Multiple elements tuples : [(60, 24, 12)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
Tuple = (5, 6, 7, 4, 9) 
print("The original tuple is : ", Tuple) 

K = "Number"
res = [element for a in Tuple for element in (a, K)] 
print("Converted Tuple with K : ", res)
# Out:
# The original tuple is :  (5, 6, 7, 4, 9)
# Converted Tuple with K :  [5, 'Number', 6, 'Number', 7, 'Number', 4, 'Number', 9, 'Number']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
List = [(-5, 6, 7), (2, 3, 4), (-3, 5, 6), (4, -6)] 
print("The original list is : " + str(List)) 

res = [sub for sub in List if all(element >= 0 for element in sub)] 

print("Positive elements Tuples : " + str(res))
# Out:
# The original list is : [(-5, 6, 7), (2, 3, 4), (-3, 5, 6), (4, -6)]
# Positive elements Tuples : [(2, 3, 4)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
test_list = [('Geeks', 1), ('for', 2), ('Geeks', 3)] 

print ("The original list is : " + str(test_list)) 

res = list(map(lambda i : i[0], test_list)).count('Geeks')

print ("The frequency of element is : " + str(res))
# Out:
# The original list is : [('Geeks', 1), ('for', 2), ('Geeks', 3)]
# The frequency of element is : 2

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
Tuple = (1, 0, 0, 1, 0, 0, 0) 

print("The original tuple is : " + str(Tuple)) 

res = int("".join(str(element) for element in Tuple), 2)  

print("Decimal number is : " + str(res))
# Out:
# The original tuple is : (1, 0, 0, 1, 0, 0, 0)
# Decimal number is : 72

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
Tuple = ("Unnati", "Bina", "Anjna")
if "Unnati" in Tuple:
    print("Yes, 'Unnati' is Present")
# Out:
# Yes, 'Unnati' is Present
