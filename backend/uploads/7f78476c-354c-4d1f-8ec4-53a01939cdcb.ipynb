# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
list1 = [(1 , 6 , 7) , (2 , 10 , 12) , (6 ,12 , 24)]

print("The Original List : " , list1)

k = 6

ans = [i for i in list1 if all(ele % k == 0 for ele in i)]

print("K Multiple Elements Tuple : " , str(ans))
# Out:
# The Original List :  [(1, 6, 7), (2, 10, 12), (6, 12, 24)]
# K Multiple Elements Tuple :  [(6, 12, 24)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
tuple1 = (1 ,3 , 5 , 6 , 7 , 10)

print("The Original Tuple : " , tuple1)

k = "And"

list1 = [ele for i in tuple1 for ele in(i , k)]

print("Coverted In List : " ,  list1)
# Out:
# The Original Tuple :  (1, 3, 5, 6, 7, 10)
# Coverted In List :  [1, 'And', 3, 'And', 5, 'And', 6, 'And', 7, 'And', 10, 'And']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
list1 = [(1 , 6 , 7) , (-1 , 3 , 10) , (-6 , -7 , -10)]

print("The Original List : " , list1)

ans = [i for i in list1 if all(ele >= 0 for ele in i)]

print("positive Elements : " , ans)
# Out:
# The Original List :  [(1, 6, 7), (-1, 3, 10), (-6, -7, -10)]
# positive Elements :  [(1, 6, 7)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
tuple = [('Python', 1), ('Data', 2), ('Python', 3)] 

print ("The Original List Is : " + str(tuple)) 

ans = list(map(lambda i : i[0], tuple)).count('Python')  

print ("The Frequency Of Element Is : " + str(ans))
# Out:
# The Original List Is : [('Python', 1), ('Data', 2), ('Python', 3)]
# The Frequency Of Element Is : 2

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
tuple = (1 , 0 , 1) 

print("The Original Tuple Is : " + str(tuple)) 
  
# using int() with base to get actual number 
ans = int("".join(str(i) for i in tuple), 2)  
  
# printing result  
print("Decimal Number Is : " + str(ans))
# Out:
# The Original Tuple Is : (1, 0, 1)
# Decimal Number Is : 5

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
tuple = (("Python", "py"), ("Data", "Science")) 

# printing tuple 
print ("The original Tuple Is : " + str(tuple)) 

if (any('Python' in i for i in tuple)) : 
    print("Python Is Present") 
else : 
    print("Python Is Not Present")
# Out:
# The original Tuple Is : (('Python', 'py'), ('Data', 'Science'))
# Python Is Present
