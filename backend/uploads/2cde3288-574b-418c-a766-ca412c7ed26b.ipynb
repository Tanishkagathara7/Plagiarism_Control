# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
# Python3 code to demonstrate working of 
# K Multiple Elements Tuples 
# Using filter() + lambda + all() 

# initializing list 
test_list = [(6, 24, 12), (7, 9, 6), (12, 18, 21)] 

# printing original list 
print("The original list is : " + str(test_list)) 

# initializing K 
K = 6

# filter() + lambda for filter operation 
res = list(filter(lambda sub: all(ele % K == 0 for ele in sub), test_list)) 

# printing result 
print("K Multiple elements tuples : " + str(res))
# Out:
# 2
# 4
# 8
# 4
# 8
# 4

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
test_tup = (5, 6, 7, 4, 9) 

# printing original tuple 
print("The original tuple is : ", test_tup) 

K = "Gfg"

 
res = [ele for sub in test_tup for ele in (sub, K)] 


print("Converted Tuple with K : ", res)
# Out:
# The original tuple is :  (5, 6, 7, 4, 9)
# Converted Tuple with K :  [5, 'Gfg', 6, 'Gfg', 7, 'Gfg', 4, 'Gfg', 9, 'Gfg']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
 
test_list = [(4, 5, 9), (-3, 2, 3), (-3, 5, 6), (4, 6)] 


print("The original list is : " + str(test_list)) 

 
res = list(filter(lambda sub: all(ele >= 0 for ele in sub), test_list)) 


print("Positive elements Tuples : " + str(res))
# Out:
# The original list is : [(4, 5, 9), (-3, 2, 3), (-3, 5, 6), (4, 6)]
# Positive elements Tuples : [(4, 5, 9), (4, 6)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
listA = [('Apple', 'Mon'), ('Apple', 'Tue'), ('Apple', 'Wed')]


print("Given list of tuples : " ,listA)


Freq_res = list(map(lambda i: i[0], listA)).count('Apple')

print("The frequency of element is : ",Freq_res)
# Out:
# Given list of tuples :  [('Apple', 'Mon'), ('Apple', 'Tue'), ('Apple', 'Wed')]
# The frequency of element is :  3

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
 
test_tup = (1, 0, 0, 1, 0, 1) 

print("The original tuple is : " + str(test_tup)) 


res = 0
for ele in test_tup: 

    res = (res << 1) | ele 

 
print("Decimal number is : " + str(res))
# Out:
# The original tuple is : (1, 0, 0, 1, 0, 1)
# Decimal number is : 37

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
n=input('Enter element to search:')

test_tuple = (("drij", "chudasama"), ("hi", "hello")) 


print ("The original tuple is " + str(test_tuple)) 


if (any(n in i for i in test_tuple)) : 
    print(n," is present") 
else : 
    print(n," is not present")
# Out:
# Enter element to search:drij
# The original tuple is (('drij', 'chudasama'), ('hi', 'hello'))
# drij  is present
