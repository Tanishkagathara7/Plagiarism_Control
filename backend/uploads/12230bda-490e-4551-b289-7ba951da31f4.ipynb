# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
input_list = [(6, 24, 12), (7, 9, 6), (12, 18, 21)]
print(input_list)
k=int(input("Enter the value of k:-"))
temp=[i for i in input_list if all( j%k==0 for j in i)]
temp
# Out:
# [(6, 24, 12), (7, 9, 6), (12, 18, 21)]
# Enter the value of k:-6
# [(6, 24, 12)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
input_tuple=(i for i in input("Enter the value of tuple:-").split(","))
input_text=input("Enter the text you want to append betwwen elements:-")
my_list=[]
for i in input_tuple:
    my_list.append(i)
    my_list.append(input_text)
my_list
# Out:
# Enter the value of tuple:-1,2,3,4,5,6
# Enter the text you want to append betwwen elements:-nd
# ['1', 'nd', '2', 'nd', '3', 'nd', '4', 'nd', '5', 'nd', '6', 'nd']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
input_list=[]
while True:
    temp=input("Enter the tuple or if wanna finish enter end:-")
    if temp=="end":
        break
    else:
        temp=tuple(int(i) for i in temp.split(","))
        input_list.append(temp)
my_list=[i for i in input_list if all(j>0 for j in i)]
my_list
# Out:
# Enter the tuple or if wanna finish enter end:-1,2,3
# Enter the tuple or if wanna finish enter end:--8,-9,4
# Enter the tuple or if wanna finish enter end:-end
# [(1, 2, 3)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
from collections import Counter
my_tuple=tuple(i for i in input("Enter the value:-").split(","))
print(Counter(my_tuple))
# Out:
# Enter the value:-1,2,3,4,5,23,4,1,2,3,6
# Counter({'1': 2, '2': 2, '3': 2, '4': 2, '5': 1, '23': 1, '6': 1})

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
my_tuple=tuple(int(i) for i in input("Enter the value in binary:-").split(","))
print(int("".join(str(i) for i in my_tuple),2))
# Out:
# Enter the value in binary:-1,0,1,0,1
# 21

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
my_tuple=(1,2,3,4,5,3,7,8,91,0)
print(my_tuple)
user_input=[int(i) for i in input("Enter the elements you want to check:-").split(",")]
for i in user_input:
    if i in my_tuple:
        print("Element {} is present in the tuple".format(i))
    else:
        print("Element {} is not present in the tuple".format(i))
# Out:
# (1, 2, 3, 4, 5, 3, 7, 8, 91, 0)
# Enter the elements you want to check:-91,0,1,3,5,34,65
# Element 91 is present in the tuple
# Element 0 is present in the tuple
# Element 1 is present in the tuple
# Element 3 is present in the tuple
# Element 5 is present in the tuple
# Element 34 is not present in the tuple
# Element 65 is not present in the tuple
