# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
test_list = [(6, 24, 12), (7, 9, 6), (12, 18, 21)] 
  

print("The original list is : " , str(test_list)) 
 
K = 6
 

list=[]
for sub in test_list:
    if all(ele % K == 0 for ele in sub):
        list.append(sub)

  
 
print("K Multiple elements tuples : " + str(list))
# Out:
# The original list is :  [(6, 24, 12), (7, 9, 6), (12, 18, 21)]
# K Multiple elements tuples : [(6, 24, 12)]

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
test_tup = (1, 2, 3, 4, 5) 
  
 
print("The original tuple is : ", test_tup) 
  
 
K = "yash"
list=[]
for sub in test_tup:
    for ele in (sub, K):
        list.append(ele)
        
list
# Out:
# The original tuple is :  (1, 2, 3, 4, 5)
# [1, 'yash', 2, 'yash', 3, 'yash', 4, 'yash', 5, 'yash']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
test_list = [(6, 24, 12), (7, -9, 6), (12, 18, 21)] 
  

print("The original list is : " , str(test_list)) 
 
K = 6
 

list=[]
for sub in test_list:
    if all(ele>0  for ele in sub):
        list.append(sub)

  
 
print("K Multiple elements tuples : " + str(list))
# Out:
# The original list is :  [(6, 24, 12), (7, -9, 6), (12, 18, 21)]
# K Multiple elements tuples : [(6, 24, 12), (12, 18, 21)]

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
A = ('Apple', 'Apple','Apple','ghcffh')


print("Given list of tuples : " ,A)

Freq_res = A.count('Apple')



print("The frequency of element is : ",Freq_res)
# Out:
# Given list of tuples :  ('Apple', 'Apple', 'Apple', 'ghcffh')
# The frequency of element is :  3

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
test_tup = (1, 1, 0) 
print("The original tuple is : " + str(test_tup)) 
x = int("".join(str(ele) for ele in test_tup), 2)    
print("Decimal number is : " ,str(x))
# Out:
# The original tuple is : (1, 1, 0)
# Decimal number is :  6

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
test_tuple = [(1, 2), (3, 4)] 
  

print ("The original tuple is " + str(test_tuple)) 
n=int(input('enter n:'))  

 
    
    
if (any(n in i for i in test_tuple)) : 
    print(n,"is present") 
else : 
    print(n,"is not present")
# Out:
# The original tuple is [(1, 2), (3, 4)]
# enter n:6
# 6 is not present
