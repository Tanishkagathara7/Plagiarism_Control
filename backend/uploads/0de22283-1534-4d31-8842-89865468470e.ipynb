# %% [markdown]
# ___
#
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Upload/Logo/DIET_Logo.svg' /></a>
# ___

# %% [markdown]
# # 01) WAP to find tuples which have all elements divisible by K from a list of tuples.

# %%
listtuple=[(11,24,-12),(20,-22,38),(17,29,37),(-16,44,58),(99,75,27)]
count=True
k=int(input("Enter the number :- "))
for a,b,c in listtuple :
    if(a%k==0 and b%k==0 and c%k==0):
        print("("+str(a)+","+str(b)+","+str(c)+")")
        count=False
if(count):
    print("There is no tuple which all element divisible by "+ str(k))
# Out:
# Enter the number :- 2
# (20,-22,38)
# (-16,44,58)

# %% [markdown]
# # 02) WAP to covert tuple into list by adding the given string after every element.

# %%
tup=('hello','how','are','you','?')
lis=[]
string=str(input("Enter the word :- "))
for i in tup:
    lis.append(i+string)
print(lis)
# Out:
# Enter the word :- is
# ['hellois', 'howis', 'areis', 'youis', '?is']

# %% [markdown]
# # 03) WAP to find Tuples with positive elements in List of tuples.

# %%
listtuple=[(11,24,-12),(20,-22,38),(17,29,37),(-16,44,58),(99,75,27),(4,5,9)]
count=True

for a,b,c in listtuple :
    if(a>0 and b>0 and c>0):
        print("("+str(a)+","+str(b)+","+str(c)+")")
        count=False
if(count):
    print("There is no tuple which all elements are positive. ")
# Out:
# (17,29,37)
# (99,75,27)
# (4,5,9)

# %% [markdown]
# # 04) WAP to find elements frequency in given tuple.

# %%
tup=(1,1,2,3,5,6,77,7,8,9,36,84,52,552,45,4,554,56,52,1,2,3,1,214,12,1,2,5,3,65,4,1,35)
num=int(input("Enter the Number find :- "))
count=0
for i in tup:
    if(i==num):
        count +=1
print("Enter number "+str(num)+" is in "+str(count)+" times.")
# Out:
# Enter the Number find :- 5
# Enter number 5 is in 2 times.

# %% [markdown]
# # 05) WAP to Convert Binary tuple to integer

# %%
tup=()
print("Press 2 for End Of the tuple ")
num=int(input("Enter the number 0 or 1 :- "))
while(num<2 and num >-1 ):
    tup = tup + (num ,)
    num=int(input("Enter the number 0 or 1 :- "))
    
print(tup)    
tup = tup[::-1]  

count=1
deci=0
for i in tup:
    deci += count*i
    count =count*2
print(deci)
# Out:
# Press 2 for End Of the tuple
# Enter the number 0 or 1 :- 1
# Enter the number 0 or 1 :- 1
# Enter the number 0 or 1 :- 0
# Enter the number 0 or 1 :- 0
# Enter the number 0 or 1 :- 6
# (1, 1, 0, 0)
# (0, 0, 1, 1)
# 12

# %% [markdown]
# # 06) WAP to check given any list elements is present in given Tuple or not.

# %%
tup=(1,1,2,3,5,6,77,7,8,9,36,84,52,552,45,4,554,56,52,1,2,3,1,214,12,1,2,5,3,65,4,1,35,1,2,3,4,8,9,10)
print("Press character  for End Of the list ")
li=[]
num=str(input("Enter the number  "))
while(num.isnumeric()):
    li.append(int(num))
    num=str(input("Enter the number :- "))
    
print(li)
count = 0
boo=False
for i in range(0,len(tup)):
    count=i
    boo=False
    for j in range(0,len(li)):
        if(count <len(tup) and tup[count]==li[j]):
            boo=True
            count += 1
        else:
            boo=False
            count += 1
          
    if(boo==True) :
        print("Enter List Present in Tuple at "+str(i+1))
# Out:
# Press character  for End Of the list
# Enter the number  1
# Enter the number :- 1
# Enter the number :- rr
# [1, 1]
# Enter List Present in Tuple at 1
# Enter List Present in Tuple at 19
# Enter List Present in Tuple at 22
# Enter List Present in Tuple at 25
# Enter List Present in Tuple at 31
# Enter List Present in Tuple at 33
